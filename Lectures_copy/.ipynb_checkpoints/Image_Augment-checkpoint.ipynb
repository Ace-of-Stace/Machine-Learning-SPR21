# %% [markdown]
# ## **Lecture: Image Data Augmentation**

# %%
# Import tensorflow.
import tensorflow as tf

# The Data Tools 
import numpy as np
import matplotlib.pyplot as plt

# Import the Keras tools.
from tensorflow import keras
from tensorflow.keras.models import Sequential

# For editing images. 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Editing the targets
from tensorflow.keras.utils import to_categorical

print("Tensorflow version:", tf.__version__)
print("Keras version:", keras.__version__, "\n")

physical_devices = tf.config.list_physical_devices('GPU') 
print("GPU's:",physical_devices)

for gpu_instance in physical_devices: 
    tf.config.experimental.set_memory_growth(gpu_instance, True)
# Out:
# Tensorflow version: 2.1.0
# Keras version: 2.2.4-tf
#
# GPU's: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
src_path_train = "../Collab/joe/proj2/training"

# %%
train_datagen = ImageDataGenerator(  # Images are altered in desirable ways
        rescale=1 / 255.0, 
        rotation_range=0,
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        zca_epsilon=1e-06,
        width_shift_range=0.0,
        height_shift_range=0.0,
        brightness_range=None,
        shear_range=0.0,
        zoom_range=0.0,
        channel_shift_range=0.0,
        fill_mode='nearest',
        cval=0.0,
        horizontal_flip=False,
        vertical_flip=False,
        preprocessing_function=None,
        data_format=None,
        dtype=None,
        validation_split=0.20)

# %%
batch_size = 3
train_generator = train_datagen.flow_from_directory( #Image pipeline that allow them to move into Keras
    directory=src_path_train,
    target_size=(300, 300),# This is probably a good size for network purposes
    color_mode="rgb",
    class_mode="categorical",
    subset='training',
    shuffle=True,
    seed=42,
    classes=None,
    batch_size=batch_size,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    interpolation='nearest')
# Out:
# Found 152 images belonging to 10 classes.

# %%
x = train_generator.next()
for i in range(batch_size):
    image = x[0][i]
    plt.imshow(image)
    plt.show()

# %% [markdown]
# ## **Other image data to explore**

# %%
#(x1_train, y1_train), (x1_test, y1_test) = tf.keras.datasets.cifar10.load_data()

# %%
#plt.matshow(x_train[0])
